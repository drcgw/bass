# %%
from bass import *
# Out:
# BASS ready!

# %%
#initialize new file
Data = {}
Settings = {}
Results ={}

############################################################################################
#manual Setting block
Settings['folder']= "/Users/abigaildobyns/Desktop/Neuron Modeling/morgan voltage data"
Settings['Label'] = 'voltage-TBModel-sec1320-eL-IP0_9.txt'
Settings['Output Folder'] = "/Users/abigaildobyns/Desktop/Neuron Modeling/morgan voltage data/IP0_9"
Settings['File Type'] = 'Morgan' #'LCPro', 'ImageJ', 'SIMA', 'Plain', 'Morgan'
Settings['Milliseconds'] = True

#transformation Settings
Settings['Absolute Value'] = False #Must be True if Savitzky-Golay is being used

Settings['Bandpass Highcut'] = 'none'
Settings['Bandpass Lowcut'] = 'none'
Settings['Bandpass Polynomial'] = 'none'

Settings['Linear Fit'] = False #between 0 and 1 on the whole time series
Settings['Linear Fit-Rolling R'] = 0.75 #between 0 and 1
Settings['Linear Fit-Rolling Window'] = 1000 #window for rolling mean for fit, unit is index
Settings['Relative Baseline'] = 0 #default 0, unless data is normalized, then 1.0

Settings['Savitzky-Golay Polynomial'] = 'none' #intiger
Settings['Savitzky-Golay Window Size'] = 'none' #must be odd, index not time

#Baseline Settings
Settings['Baseline Type'] = 'static' #'linear', 'rolling', or 'static'
Settings['Rolling Baseline Window'] = 'none' #leave as 'none' if linear or static

#Peaks
Settings['Delta'] = 10
Settings['Peak Minimum'] = -(np.Inf) #amplitude value
Settings['Peak Maximum'] = np.Inf #amplitude value

#Bursts
Settings['Burst Area'] = False #calculate burst area
Settings['Exclude Edges'] = True #False to keep edges, True to discard them
Settings['Inter-event interval minimum (seconds)'] = 0.700 #only for bursts, not for peaks
Settings['Maximum Burst Duration (s)'] = 10 
Settings['Minimum Burst Duration (s)'] = 0
Settings['Minimum Peak Number'] = 1 #minimum number of peaks/burst, integer
Settings['Threshold']= -40 #linear: proportion of baseline. 
                           #static: literal value.
                           #rolling, linear ammount grater than rolling baseline at each time point.

#Outputs
Settings['Generate Graphs'] = False #create and save the fancy graph outputs
Settings['Graph LCpro events'] = False 
############################################################################################

# %%
#Load in a Settings File
#initialize new file
Data = {}
Settings = {}
Results ={}

############################################################################################
#manual Setting block
Settings['folder']= "/Users/abigaildobyns/Desktop/Neuron Modeling/morgan voltage data"
Settings['Label'] = 'voltage-TBModel-sec1320-eL-IP0_9.txt'
Settings['Output Folder'] = "/Users/abigaildobyns/Desktop/Neuron Modeling/morgan voltage data/IP0_9"
Settings['File Type'] = 'Morgan' #'LCPro', 'ImageJ', 'SIMA', 'Plain', 'Morgan'
Settings['Milliseconds'] = True

#Load a Settings file
Settings['Settings File'] = '/Users/abigaildobyns/Desktop/Neuron Modeling/morgan voltage data/IP0_9/voltage-TBModel-sec1320-eL-IP0_9.txt_Settings.csv'
Settings = load_settings(Settings)

# %%
Data, Settings, Results = analyze(Data, Settings, Results)
# Out:
# Made plots folder
# Data Loaded
# Transformation completed
# Baseline set completed
# -60
#  has no peaks.
# -65
#  has no peaks.
# Peak Detection completed
# -40has no bursts.
# -45has no bursts.
# -50has no bursts.
# -60has no bursts.
# -65has no bursts.
# Burst Detection completed
# Analysis Complete:
#  281.9134  Seconds
#
# --------------------------------------------
# Data Column Names/Keys
# -----
# -40
# -45
# -50
# -55
# -60
# -65
#
# --------------------------------------------
# Available Measurements from Peaks for further analysis:
# -----
# Intervals
# Peaks Amplitude
#
# --------------------------------------------
# Available Measurements from Bursts for further analysis:
# -----
# Burst Start
# Burst End
# Burst Duration
# Edge Event
# Interburst Interval
# Total Cycle Time
# Peaks per Burst
# Peak Amp
# Peak Time
# Attack
# Decay
# Intraburst Frequency
# Event Detection Complete!

# %%
display_settings(Settings)
# Out:
#                                                                                     Value
# Absolute Value                                                                      False
# Bandpass Highcut                                                                     none
# Bandpass Lowcut                                                                      none
# Bandpass Polynomial                                                                  none
# Baseline Type                                                                      static
# Burst Area                                                                          False
# Delta                                                                                  10
# Exclude Edges                                                                        True
# File Type                                                                          Morgan
# Generate Graphs                                                                     False
# Graph LCpro events                                                                  False
# Inter-event interval minimum (seconds)                                                0.7
# Label                                                voltage-TBModel-sec1320-eL-IP0_9.txt
# Linear Fit                                                                          False
# Linear Fit-Rolling R                                                                 0.75
# Linear Fit-Rolling Window                                                            1000
# Maximum Burst Duration (s)                                                             10
# Milliseconds                                                                         True
# Minimum Burst Duration (s)                                                              0
# Minimum Peak Number                                                                     1
# Output Folder                           /Users/abigaildobyns/Desktop/Neuron Modeling/m...
# Peak Maximum                                                                          inf
# Peak Minimum                                                                         -inf
# Relative Baseline                                                                    5000
# Rolling Baseline Window                                                              none
# Sample Rate (s/frame)                                                              0.0001
# Savitzky-Golay Polynomial                                                            none
# Savitzky-Golay Window Size                                                           none
# Threshold                                                                             -40
# folder                                  /Users/abigaildobyns/Desktop/Neuron Modeling/m...
# plots folder                            /Users/abigaildobyns/Desktop/Neuron Modeling/m...
#
# [31 rows x 1 columns]

# %%
#grouped summary for peaks
Results['Peaks-Master'].groupby(level=0).describe()
# Out:
#               Intervals  Peaks Amplitude
# -40 count  97640.000000     97641.000000
#     mean       0.013519         5.233148
#     std        0.000105         0.054848
#     min        0.009900         4.199563
#     25%        0.013500         5.194647
#     50%        0.013500         5.247812
#     75%        0.013500         5.279839
#     max        0.013600         6.059153
# -45 count  58129.000000     58130.000000
#     mean       0.022708         5.531830
#     std        0.000383         0.053229
#     min        0.012200         5.051321
#     25%        0.022700         5.491272
#     50%        0.022700         5.546603
#     75%        0.022800         5.579919
#     max        0.022800         5.867028
# -50 count  13813.000000     13814.000000
#     mean       0.095556         5.478880
#     std        0.004578         0.053040
#     min        0.019700         5.361490
#     25%        0.095900         5.438350
#     50%        0.095900         5.493306
#     75%        0.095900         5.526307
#     max        0.096000         5.760678
# -55 count    396.000000       397.000000
#     mean       3.304960         5.618682
#     std        0.000049         0.052198
#     min        3.304900         5.501563
#     25%        3.304900         5.579021
#     50%        3.305000         5.626661
#     75%        3.305000         5.667976
#     max        3.305000         5.678225
# -60 count      0.000000         0.000000
#     mean            NaN              NaN
#     std             NaN              NaN
#     min             NaN              NaN
#     25%             NaN              NaN
#     50%             NaN              NaN
#     75%             NaN              NaN
#     max             NaN              NaN
# -65 count      0.000000         0.000000
#     mean            NaN              NaN
#     std             NaN              NaN
#     min             NaN              NaN
#     25%             NaN              NaN
#     50%             NaN              NaN
#     75%             NaN              NaN
#     max             NaN              NaN
#
# [48 rows x 2 columns]

# %%
#grouped summary for bursts
Results['Bursts-Master'].groupby(level=0).describe()
# Out:
#            Burst Start    Burst End  Burst Duration Edge Event  \
# -55 count   397.000000   397.000000      397.000000        397
#     mean    663.722380   663.727415        0.005035          0
#     std     379.238415   379.238414        0.000048          0
#     min       9.340401     9.345501        0.005000      False
#     25%     336.531325   336.536426        0.005000      False
#     50%     663.722350   663.727350        0.005000          0
#     75%     990.913275   990.918375        0.005100      False
#     max    1318.104500  1318.109500        0.005100      False
#
#            Interburst Interval  Total Cycle Time  Peaks per Burst    Peak Amp  \
# -55 count           396.000000        396.000000              397  397.000000
#     mean              3.299925          3.304960                1    5.618682
#     std               0.000043          0.000049                0    0.052198
#     min               3.299900          3.304900                1    5.501563
#     25%               3.299900          3.304900                1    5.579021
#     50%               3.299900          3.305000                1    5.626661
#     75%               3.299900          3.305000                1    5.667976
#     max               3.300000          3.305000                1    5.678225
#
#              Peak Time      Attack       Decay  Intraburst Frequency
# -55 count   397.000000  397.000000  397.000000            397.000000
#     mean    663.725003    0.002623    0.002412            198.636805
#     std     379.238384    0.000054    0.000057              1.869847
#     min       9.343100    0.002501    0.002301            196.074587
#     25%     336.534000    0.002592    0.002366            196.078431
#     50%     663.725000    0.002632    0.002421            200.000000
#     75%     990.915900    0.002667    0.002459            200.000000
#     max    1318.107100    0.002699    0.002500            200.000000
#
# [8 rows x 12 columns]

# %%
#Call one time series by Key
roi = '-55'
graph_detected_events_display(Data, Settings, Results, roi)

# %%
#Get average plots, display only
event_type = 'peaks'
meas = 'Peaks Amplitude'
average_measurement_plot(event_type, meas,Results)

# %%
#raster
raster(Results)

# %%
#Histogram Entropy
event_type = 'Bursts'
meas = 'all'
Results = histent_wrapper(event_type, meas, Data, Settings, Results)
Results['Histogram Entropy']
# Out:
# All Bursts measurements analyzed.
#      Intervals  Peaks Amplitude  Burst Start  Burst End  Burst Duration  \
# -40   0.012025         0.320293          NaN        NaN             NaN
# -45   0.016370         0.516087          NaN        NaN             NaN
# -50   0.022428         0.722515          NaN        NaN             NaN
# -55   0.238110         0.894526     0.978558   0.978558        0.227993
# -60        NaN              NaN          NaN        NaN             NaN
# -65        NaN              NaN          NaN        NaN             NaN
#
#      Edge Event  Interburst Interval  Total Cycle Time  Peaks per Burst  \
# -40         NaN                  NaN               NaN              NaN
# -45         NaN                  NaN               NaN              NaN
# -50         NaN                  NaN               NaN              NaN
# -55           0             0.197494           0.23811                0
# -60         NaN                  NaN               NaN              NaN
# -65         NaN                  NaN               NaN              NaN
#
#      Peak Amp  Peak Time    Attack     Decay  Intraburst Frequency
# -40       NaN        NaN       NaN       NaN                   NaN
# -45       NaN        NaN       NaN       NaN                   NaN
# -50       NaN        NaN       NaN       NaN                   NaN
# -55  0.894526   0.978558  0.936493  0.967943              0.227993
# -60       NaN        NaN       NaN       NaN                   NaN
# -65       NaN        NaN       NaN       NaN                   NaN
#
# [6 rows x 14 columns]

# %%
#Moving Stats
event_type = 'Peaks'
meas = 'all'
window = 60 #seconds
Results = moving_statistics(event_type, meas, window, Data, Settings, Results)

# %%
moving_statistics?
